# %%
import pandas as pd
import numpy as np
import pytesseract
import mss

from glob import glob

import matplotlib.pyplot as plt

# %%
# Read current monitors information
for monitor in mss.mss().monitors:
	print(monitor)

# %%
img_names = glob("../samples/*")
img_names

# %%
img_idx = 1
img_name = img_names[img_idx]

fig, ax = plt.subplots(figsize=[20, 20])
ax.imshow(plt.imread(img_name))

# Use OCR
img_texts = pytesseract.image_to_string(img_name, lang='eng')
print(img_texts)
