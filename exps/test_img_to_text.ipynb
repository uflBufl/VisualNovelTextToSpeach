# %%
import pandas as pd
import numpy as np
import pytesseract

from glob import glob

import matplotlib.pyplot as plt

# %%
img_names = glob("../samples/*")
img_names

# %%
fig, ax = plt.subplots(figsize=[20, 20])
ax.imshow(plt.imread(img_names[0]))

# %%
# Use OCR
img_texts = pytesseract.image_to_string(img_names[0], lang='eng')
print(img_texts)
